# %%
for i in range(20):
    print(2**i)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
# 524288

# %%
import struct
import sys
import math
import string
import os.path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import wave

# %%
plt.rcParams.keys
# Out:
# /home/tetsu/personal_files/sound_programming/venv/lib/python3.7/site-packages/IPython/lib/pretty.py:697: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   output = repr(obj)
# <bound method Mapping.keys of RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
# ...

# %%
np.arange(0,65536/48000, dtype=np.float64)
# Out:
# array([0., 1.])
